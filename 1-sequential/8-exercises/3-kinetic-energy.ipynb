# %% [markdown]
# # Εκφώνηση
#
# H κινητική ενέργεια είναι απλώς η ενέργεια που έχει ένα αντικείμενο λόγω της
# κίνησής του. Με έναν απλό τρόπο θα μπορούσαμε να πούμε ότι κάθε αντικείμενο που
# κινείται έχει κινητική ενέργεια.
# Η κινητική ενέργεια εξαρτάται από δύο βασικούς παράγοντες: τη μάζα του
# αντικειμένου και την ταχύτητά του και υπολογίζεται από τον τύπο:
# $$E = \frac{1}{2} \cdot m \cdot v^2$$
#
# Όσο μεγαλύτερη είναι η μάζα και η ταχύτητα, τόσο περισσότερη κινητική ενέργεια
# θα έχει το αντικείμενο. Η αύξηση της ταχύτητας προκαλεί σημαντική αύξηση της
# ενέργειας, αφού η ενέργεια εξαρτάται από την ταχύτητα τετραγωνικά.
#
# Να γράψετε πρόγραμμα σε Python που:
# 1. Διαβάζει τη μάζα του σώματος $m$,
# 2. Διαβάζει τη ταχύτητά του $v$,
# 3. Υπολογίζει την κινητική ενέργεια $E$ σύμφωνα με τον παραπάνω τύπο.
# 4. Εμφανίζει μήνυμα με το αποτέλεσμα του υπολογισμού.
