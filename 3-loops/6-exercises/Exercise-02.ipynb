# %% [markdown]
# # Εκφώνηση
#
# Γράψτε πρόγραμμ το οποίο να διαβάζει το βαθμό για καθέναν από τους 25 μαθητές
# μιας τάξης και να εκτυπώνει τον αντίστοιχο χαρακτηρισμό, σύμφωνα με τον πίνακα
# που ακολουθεί. Σε περίπτωση που ο βαθμός που θα δοθεί είναι μικρότερος του 0 ή
# μεγαλύτερος του 20 να εμφανίζεται μήνυμα «Άκυρη βαθμολογία».
#
# |    Βαθμός   | Χαρακτηρισμός |
# |:-----------:|---------------|
# |   0 - 9.4   | Απορρίπτεται  |
# |  9.5 - 13.4 | Μέτρια        |
# | 13.5 - 15.4 | Καλά          |
# | 15.5 - 17.4 | Πολύ καλά     |
# |  17.5 - 20  | Άριστα        |
#
# ## Υπόδειξη
# 1. Γνωρίζουμε το πλήθος των μαθητών, άρα και τη δομή επανάληψης που θα
#    χρησιμοποήσουμε.
# 2. Σε κάθε επανάληψη θα πρέπει να διαβάζουμε ένα βαθμό και να ελέγχουμε με δομή
#    πολλαπλής επιλογής (`if ... elif ...)`.
# 3. Χρησιμοποιήστε τον παρακάτω "σκελετό" αντικαθιστόντας τα κενά με τις
#    κατάλληλες εντολές.
#
# ```python
# for ____:
#     vathmos = ____(input___)
#     if vathmos _____:
#         print(_____)
#     elif vathmos _____:
#         print(____)
#     elif ____:
#         print(____)
#     elif ____:
#         print(____)
#     elif ____:
#         print(____)
#     else:
#         print(____)
# ```
