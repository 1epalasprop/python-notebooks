# %% [markdown]
# # ΣΥΝΑΡΤΗΣΕΙΣ ΟΡΙΖΟΜΕΝΕΣ ΑΠΟ ΤΟ ΧΡΗΣΤΗ
# ## ΜΕΡΟΣ 2ο
# ### Συναρτήσεις που επιστρέφουν τιμή
#
# Η παρακάτω συνάρτηση υπολογίζει το άθροισμα δύο αριθμών και στη συνέχεια το **επιστρέφει**.
# ```
# def sum2(x,y):
# 	result=x+y
# 	return result
# ```
# Στο κελί που ακολουθεί ξαναγράψτε τη συνάρτηση και *καλέστε* την για τους αριθμούς 12 και 10. Φροντίστε να εκτυπώσετε το αποτέλεσμα.

# %% [markdown]
# Στο κελί που ακολουθεί ξαναγράψτε τον ορισμό της sum2, αλλά αυτή τη φορά καλέστε την για δύο αριθμούς x και y που δίνει ο χρήστης.

# %% [markdown]
# Ξαναγράψτε τον ορισμό της sum2 και καλέστε την για δύο αριθμούς p και q που δίνει ο χρήστης. Τι παρατηρείτε; Έχει σημασία πώς θα ονομάσουμε τις μεταβλητές μέσα ή έξω από τη συνάρτηση; Μπορούν να έχουν το ίδιο όνομα;

# %% [markdown]
# Ξαναγράψτε τον ορισμό της sum2, αλλά αυτή τη φορά καλέστε την για τις συμβολοσειρές "Hello" και "world". Ποια τιμή επέστρεψε η συνάρτηση; Τι συμπέρασμα βγάζετε;

# %% [markdown]
# ### Άσκηση 1
# Στο κελί που ακολουθεί να γραφτεί πρόγραμμα το οποίο:
# - ορίζει μια συνάρτηση με όνομα sum4, η οποία δέχεται 4 αριθμούς (a, b, c, d), τους προσθέτει και επιστρέφει το αποτέλεσμα
# - Στη συνέχεια το πρόγραμμα διαβάζει 4 αριθμούς a, b, c και d
# - Καλεί τη συνάρτηση για να υπολογίσει το άθροισμα των αριθμών
# - Εμφανίζει το αποτέλεσμα στην οθόνη

# %% [markdown]
# ### Άσκηση 2
# Στο κελί που ακολουθεί να γραφτεί πρόγραμμα το οποίο:
# - ορίζει μια συνάρτηση με όνομα product3, η οποία δέχεται 3 αριθμούς (a, b, c), τους πολλαπλασιάζει και επιστρέφει το αποτέλεσμα
# - Στη συνέχεια το πρόγραμμα διαβάζει 3 αριθμούς a, b, c
# - Καλεί τη συνάρτηση για να υπολογίσει το *γινόμενο* των αριθμών
# - Εμφανίζει το αποτέλεσμα στην οθόνη

# %% [markdown]
# ### Άσκηση 3
# Να γραφτεί πρόγραμμα το οποίο:
# - ορίζει μια συνάρτηση με όνομα f1 η οποία δέχεται δύο αριθμούς x και y και υπολογίζει την τιμή της παράστασης x*y + 2x
# - Διαβάζει δύο αριθμούς x και y
# - Καλεί τη συνάρτηση f1 και εμφανίζει το αποτέλεσμα στην οθόνη

# %% [markdown]
# ### Άσκηση 4
# Να γραφτεί πρόγραμμα το οποίο:
# - ορίζει μια συνάρτηση με όνομα emvado_trigonou, η οποία δέχεται 2 αριθμούς vasi και ipsos που αντιστοιχούν στη βάση και στο ύψος ενός τριγώνου και υπολογίζει και επιστρέφει το εμβαδό του (1/2*vasi`*ipsos)
# - Διαβάζει τη βάση και το ύψος του τριγώνου
# - Καλεί τη συνάρτηση για να υπολογίσει το εμβαδό του
# - εμφανίζει το αποτέλεσμα στην οθόνη

# %% [markdown]
# ### Άσκηση 5
# Να γραφτεί πρόγραμμα το οποίο:
# - ορίζει μια συνάρτηση με όνομα emvado_tetragonou, η οποία δέχεται ένα αριθμό a που αντιστοιχεί στην πλευρά ενός τετραγώνου και υπολογίζει και επιστρέφει το εμβαδό του (E=$a^{2}$).
# - Διαβάζει την πλευρά a ενός τετραγώνου
# - Καλεί τη συνάρτηση για να υπολογίσει το εμβαδό του
# - εμφανίζει το αποτέλεσμα στην οθόνη

# %% [markdown]
# ### Άσκηση 6
# Να γραφτεί πρόγραμμα το οποίο:
# - Oρίζει μια συνάρτηση με όνομα emvado_kiklou, η οποία δέχεται ένα αριθμό R που αντιστοιχεί στην ακτίνα ενός κύκλου και υπολογίζει και επιστρέφει το εμβαδό του (3.14*$R^{2}$)
# - Διαβάζει την ακτίνα R ενός κύκλου
# - Καλεί τη συνάρτηση για να υπολογίσει το εμβαδό του
# - Eμφανίζει το αποτέλεσμα στην οθόνη
# - Oρίζει μια συνάρτηση με όνομα perimetros_kiklou, η οποία δέχεται ένα αριθμό R που αντιστοιχεί στην ακτίνα ενός κύκλου και υπολογίζει και επιστρέφει την περίμετρό του (2`*3.14`*R)
# - Καλεί τη συνάρτηση για να υπολογίσει την περίμετρο του κύκλου
# - Eμφανίζει το αποτέλεσμα στην οθόνη
